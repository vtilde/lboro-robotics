# %% [markdown]
# # Person Following and Safe Distance Navigation for Task 2
#
# For Task 2, the objective is to enable the robot to autonomously follow a manually selected person using visual tracking, while maintaining a safe and consistent distance. To achieve this, we combined ZED stereo vision, object tracking and robot control in a closed-loop system.

# %% [markdown]
# ## Import Required Libraries

# %%
import numpy as np
import ipywidgets.widgets as widgets
import time
from IPython.display import display
import cv2
import pyzed.sl as sl

# %% [markdown]
# ## Setup Live Display Widgets
#
# To visualise the robot's perception in real-time, we use IPython widgets to display the raw and annotated frames side-by-side. This assists with visual debugging during object detection and tracking.

# %%
image_display = widgets.Image(format="jpeg", width="45%")
full_display = widgets.Image(format="jpeg", width="45%")
display(widgets.HBox([image_display, full_display]))

location_coords_display = widgets.Label()
display(location_coords_display)

# %% [markdown]
# ## Initialise ZED Camera
#
# The ZED camera is configured with VGA resolution and precise depth mode in millimetres. We ensure successful initialisation before continuing to tracking logic.

# %%
camera = sl.Camera()
camera_params = sl.InitParameters()
camera_params.camera_resolution = sl.RESOLUTION.VGA
camera_params.depth_mode = sl.DEPTH_MODE.ULTRA
camera_params.coordinate_units = sl.UNIT.MILLIMETER

camera_status = camera.open(camera_params)
if camera_status != sl.ERROR_CODE.SUCCESS:
    print("camera error")
    print(camera_status)
    camera.close()
    exit()

# %% [markdown]
# ## Initialise Robot and Tracking Model
#
# The robot hardware is controlled via a motors module, which contains essential movement functions. We initialise the robot instance and stop all motors immediately to ensure safety before any movement logic executes.
#
# For tracking, we import a **main.Model** class which wraps a **pretrained YOLO object detector** (yolo11n.engine) and provides persistent tracking functionality. This includes:
# - Assigning object IDs from the YOLO engine
# - Selecting a target to track by ID
# - Handling lost targets and re-identifying based on location and histogram similarity
#
# This logic used the **Ultralytics pretrained YOLO backend** to detect humans (class 0) in each frame.

# %%
# Initialise robot
import motors
robot = motors.MotorsYukon()
robot.stop()

# Initialise model
import main
m = main.Model()

# %% [markdown]
# ## Select Target for Tracking
#
# We retrieve the live camera feed, annotate it with bounding boxes and prompt the user to manually select a person to track by entering the corresponding ID. Once selected, the system locks onto this target.

# %%
image_mat = sl.Mat()
depth_mat = sl.Mat()
started_tracking = False

# Loop until a valid tracking target is selected by the user
while not started_tracking:
    err = camera.grab()
    if err == sl.ERROR_CODE.SUCCESS:
        camera.retrieve_image(image_mat)
        image = image_mat.get_data()
        
        # Display the current frame with all detected bounding boxes
        image_display.value = m.show_all_boxes(image)
    
        user_input = input("enter id to track (or leave blank to skip):")
        if user_input == "":
            continue
        else:
            # Set the selected ID as the tracked target
            m.tracked_id = int(user_input)
            print("tracking object id " + str(user_input))
            started_tracking = True

# %% [markdown]
# ## Define Robot Motion Parameters
#
# These constants control how the robot adjusts its direction and distance when tracking:
#
# - KEEP_X_BETWEEN = (275, 417): Horizontal range (in pixels) where the person is considered centred. Outside this, the robot turns.
# - TURN_SPEED = 0.3: Speed of turning movement.
# - TURN_SLEEP = 0.05: Time delay after each turn to avoid overshooting.
# - KEEP_DEPTH_BETWEEN = (1500, 2000): Safe distance range (in mm) between the robot and the person.
# - MOVE_SPEED = 0.6: Speed of forward/backward movement.
# - MOVE_SLEEP = 0.05: Time delay after each move for controlled motion.

# %%
KEEP_X_BETWEEN = (275, 417)
TURN_SPEED = 0.3
TURN_SLEEP = 0.05
KEEP_DEPTH_BETWEEN = (1500, 2000)
MOVE_SPEED = 0.6
MOVE_SLEEP = 0.05

# %% [markdown]
# ## Real-Time Person-Following Logic
#
# The robot runs a continuous loop:
# - Captures the latest RGB and depth data.
# - Tracks the selected person using the model.
# - Calculates their horizontal position and distance.
# - Commands the robot to turn or move forward/backward accordingly.
# - If the target is lost, the robot halts immediately.
#
# Live image feedback with bounding boxes is updated at every iteration.

# %%
# Continuously grabs frames and updates robot movement based on tracked person's position
running = True
while running:
    err = camera.grab()
    if err == sl.ERROR_CODE.SUCCESS:
        # Retrieve image and depth data from the camera
        camera.retrieve_image(image_mat)
        image = image_mat.get_data()

        camera.retrieve_measure(depth_mat, measure=sl.MEASURE.DEPTH)
        depth = depth_mat.get_data()
        
        tracked_box = m.track(image, return_type="corners")
        
        if tracked_box is False:
            # If person is not detected, stop the robot and show image
            image_display.value = bytes(cv2.imencode('.jpg', image)[1])
            robot.stop()
        else:
            # Calculate the centre of the tracked bounding box
            x_centre = int((tracked_box[0] + tracked_box[2]) / 2)
            y_centre = int((tracked_box[1] + tracked_box[3]) / 2)
            image_rect = cv2.rectangle(
                image,
                (int(tracked_box[0]), int(tracked_box[1])),
                (int(tracked_box[2]), int(tracked_box[3])),
                (255, 0, 0),
                4
            )
            image_display.value = bytes(cv2.imencode('.jpg', image_rect)[1])

            # Turn if tracked person is outside KEEP_X_BETWEEN
            if x_centre < KEEP_X_BETWEEN[0]:
                robot.left(speed=TURN_SPEED)
                time.sleep(TURN_SLEEP)
                print("turning left   ", end="\r")
            elif x_centre > KEEP_X_BETWEEN[1]:
                robot.right(speed=TURN_SPEED)
                time.sleep(TURN_SLEEP)
                print("turning right  ", end="\r")
            else:
                # Adjust correct distance if person is centred
                depth_value = depth[y_centre, x_centre]
                print(depth_value)
                if depth_value < KEEP_DEPTH_BETWEEN[0]:
                    robot.backward(speed=MOVE_SPEED)
                    time.sleep(MOVE_SLEEP)
                    print("turning back   ", end="\r")
                elif depth_value > KEEP_DEPTH_BETWEEN[1]:
                    robot.forward(speed=MOVE_SPEED)
                    time.sleep(MOVE_SLEEP)
                    print("turning forward", end="\r")
                else:
                    # Person is centred and at a safe distance — stop moving
                    robot.stop()
                    print("stopping       ", end="\r")

        full_display.value = m.show_all_boxes(image)
    
# Close the camera when tracking ends
camera.close()
# Out:
# HBox(children=(Image(value=b'', format='jpeg', width='45%'), Image(value=b'', format='jpeg', width='45%')))
# Label(value='')
# [2025-05-07 11:43:38 UTC][ZED][INFO] Logging level INFO
# [2025-05-07 11:43:38 UTC][ZED][INFO] Logging level INFO
# [2025-05-07 11:43:38 UTC][ZED][INFO] Logging level INFO
# [2025-05-07 11:43:39 UTC][ZED][INFO] [Init]  Depth mode: ULTRA
# [2025-05-07 11:43:40 UTC][ZED][INFO] [Init]  Camera successfully opened.
# [2025-05-07 11:43:40 UTC][ZED][INFO] [Init]  Camera FW version: 1523
# [2025-05-07 11:43:40 UTC][ZED][INFO] [Init]  Video mode: VGA@100
# [2025-05-07 11:43:40 UTC][ZED][INFO] [Init]  Serial Number: S/N 38559894
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Loading yolo11n.engine for TensorRT inference...
# [05/07/2025-12:43:45] [TRT] [I] Loaded engine size: 12 MiB
# [05/07/2025-12:43:45] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [05/07/2025-12:43:45] [TRT] [I] [MemUsageChange] TensorRT-managed allocation in IExecutionContext creation: CPU +0, GPU +18, now: CPU 0, GPU 28 (MiB)
# enter id to track (or leave blank to skip): 1
# tracking object id 1
# 2156.092
# 2018.8047orward
# 1830.5281orward
# 1704.7145
# 1749.1368
# 1740.268
# 1774.8849
# 1816.8275
# 1862.2815
# 1939.7996
# 2001.7268
# 2134.2073orward
# 2121.3403orward
# 2085.6265orward
# 2021.1686orward
# 1919.5089orward
# 1827.12g
# 1800.7797
# 1726.8352
# 1604.1819eft
# 1497.5181
# 1465.9336ack
# 1488.2257ack
# 1607.3795ack
# 1615.3778eft
# 1637.4213
# 1627.6641
# 1597.1511
# 1521.4459
# 1466.526
# 1471.689back
# 1618.6321eft
# 1841.6927
# 1870.7651
# 1763.7526
# 1702.1322eft
# 1890.4225
# 1951.4983
# 1923.1707
# 1885.2657
# nanning left
# 2292.3325
# 2214.5847orward
# 2125.4294orward
# 2071.1846orward
# 2067.7747orward
# 2011.3257orward
# 2028.9952orward
# 2102.1106eft
# 2057.8076orward
# 2062.0317orward
# 2058.5247orward
# 2279.5198orward
# 2067.6777orward
# 2086.6863orward
# 2139.0874orward
# 2209.0857orward
# 2196.0532orward
# 2200.8257orward
# 2260.8318orward
# 2291.4739orward
# 2299.9092orward
# 2338.0063orward
# 2213.8208orward
# 2087.4246orward
# 2093.7742orward
# 1825.8065orward
# 1687.0624
# 1550.8033
# 1478.8119
# 1351.6229ack
# 1342.6941ack
# 1377.8284ack
# 1322.0297ack
# 1249.0531ack
# 1303.0813ack
# 1212.539back
# 1238.4745ack
# 1183.1968ack
# 1229.8757ack
# 1272.5338ack
# 1391.8896ack
# 7221.389left
# 1249.9156orward
# 1175.8019ack
# 1340.7273ack
# 1479.5487ack
# 1545.217back
# 1627.0171
# 1608.7632
# 1619.6228
# 1632.8596
# 1647.2634
# 1631.8455
# 1638.8235
# 1655.5413
# new box id: tensor(77.)
#     coords:  tensor([227.4055, 189.1841, 253.6175, 228.0359])
# last known:  tensor([247.5856,   7.8309, 380.4957, 274.4156])
# [tensor(True), tensor(False), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(1.)
#     coords:  tensor([254.3536,   1.3710, 388.5321, 277.1629])
# last known:  tensor([247.5856,   7.8309, 380.4957, 274.4156])
# [tensor(True), tensor(True), tensor(True), tensor(True)]
# 4
#
# 1501.6604
# 1387.1301
# 1148.5618ack
# 1148.5193ack
# 948.1584back
# 1109.3287ack
# 1240.8833ack
# 1459.9661ack
# 1745.0114ack
# new box id: tensor(94.)
#     coords:  tensor([184.6232, 152.0424, 233.3405, 226.7837])
# last known:  tensor([284.7762,  22.5546, 393.4975, 286.2817])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(95.)
#     coords:  tensor([  0.0000, 147.2506,  20.1777, 220.1589])
# last known:  tensor([284.7762,  22.5546, 393.4975, 286.2817])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(1.)
#     coords:  tensor([262.3892,   6.1605, 480.2149, 297.6440])
# last known:  tensor([284.7762,  22.5546, 393.4975, 286.2817])
# [tensor(True), tensor(True), tensor(False), tensor(True)]
# 3
#
# nan
# new box id: tensor(102.)
#     coords:  tensor([291.8489,  82.8523, 384.6551, 269.3484])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(True), tensor(False), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(103.)
#     coords:  tensor([280.7177, 178.8354, 315.0935, 236.7050])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(104.)
#     coords:  tensor([306.0761, 194.6190, 321.9334, 224.7880])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(1.)
#     coords:  tensor([3.8761e+02, 1.7600e-01, 5.9232e+02, 2.9551e+02])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(102.)
#     coords:  tensor([289.4717,  88.5619, 381.0855, 270.8000])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(True), tensor(False), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(103.)
#     coords:  tensor([280.9572, 178.9942, 315.3621, 237.3695])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(1.)
#     coords:  tensor([458.6388,   0.0000, 650.5491, 282.0522])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(102.)
#     coords:  tensor([290.7278,  93.3799, 379.0454, 245.0179])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(102.)
#     coords:  tensor([297.6053,  97.7009, 381.2194, 255.5329])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(True), tensor(False), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(109.)
#     coords:  tensor([158.5516, 207.1708, 181.3208, 237.5476])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(1.)
#     coords:  tensor([5.1876e+02, 1.5018e-01, 6.7200e+02, 2.8819e+02])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(109.)
#     coords:  tensor([158.5729, 207.2980, 181.1927, 237.5874])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(110.)
#     coords:  tensor([1.2977e-01, 4.3939e+01, 3.1738e+01, 2.1879e+02])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(1.)
#     coords:  tensor([535.2948,   0.0000, 672.0000, 287.8988])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(109.)
#     coords:  tensor([158.6210, 207.3803, 181.2816, 237.4520])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(1.)
#     coords:  tensor([560.7148,   0.0000, 672.0000, 287.0158])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(112.)
#     coords:  tensor([316.8795, 105.9426, 397.9840, 172.5852])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(109.)
#     coords:  tensor([158.9570, 206.7568, 181.1675, 237.7145])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(1.)
#     coords:  tensor([5.5820e+02, 7.6056e-02, 6.7200e+02, 2.8739e+02])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(112.)
#     coords:  tensor([320.1672, 106.9884, 400.9088, 172.2986])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(109.)
#     coords:  tensor([158.6550, 207.1614, 181.1875, 237.9324])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(1.)
#     coords:  tensor([555.9932,   0.0000, 672.0000, 269.4599])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(112.)
#     coords:  tensor([320.4525, 106.9570, 401.0831, 172.5421])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(1.)
#     coords:  tensor([5.5904e+02, 4.1009e-01, 6.7200e+02, 2.8052e+02])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(112.)
#     coords:  tensor([318.2506, 104.6070, 400.4201, 172.6369])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(114.)
#     coords:  tensor([457.3021,  86.1473, 543.2239, 167.1918])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(110.)
#     coords:  tensor([1.3291e-01, 1.4766e+01, 5.3474e+01, 2.2280e+02])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(1.)
#     coords:  tensor([566.4143,   0.7991, 672.0000, 289.4480])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(112.)
#     coords:  tensor([311.2712,  98.9678, 398.7983, 170.8942])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(110.)
#     coords:  tensor([5.0468e-02, 2.5844e+01, 5.0448e+01, 2.2220e+02])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(1.)
#     coords:  tensor([5.8168e+02, 2.0262e-01, 6.7200e+02, 2.8692e+02])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(110.)
#     coords:  tensor([  0.0000,  94.7059,  51.5490, 231.5234])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(102.)
#     coords:  tensor([300.5660,  86.5950, 388.7303, 268.7233])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(True), tensor(False), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(1.)
#     coords:  tensor([593.4405,   0.0000, 672.0000, 286.4963])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(110.)
#     coords:  tensor([  0.0000, 132.5143,  50.9484, 236.6776])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(102.)
#     coords:  tensor([296.7384,  78.6613, 388.8628, 271.4688])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(True), tensor(False), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(1.)
#     coords:  tensor([597.3283,   0.0000, 672.0000, 287.0016])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(110.)
#     coords:  tensor([  0.0000, 146.1057,  43.3973, 235.9374])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(102.)
#     coords:  tensor([291.9597,  66.0585, 390.4079, 276.5625])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(True), tensor(False), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(1.)
#     coords:  tensor([5.9853e+02, 8.7153e-02, 6.7200e+02, 2.8309e+02])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(102.)
#     coords:  tensor([288.2080,  48.3095, 397.4420, 276.4974])
# last known:  tensor([257.7432,   1.8163, 492.5209, 299.6927])
# [tensor(True), tensor(True), tensor(False), tensor(True)]
# 3
#
# 1837.416
# 1560.069
# 1315.1815
# 1204.2039ack
# 1188.1887ack
# 944.9527back
# 1098.6802ack
# 1400.5406ack
# 1729.7755ack
# 1932.9725
# 2042.0917
# 2185.0913orward
# new box id: tensor(143.)
#     coords:  tensor([230.8548,   0.0000, 466.9212, 307.3651])
# last known:  tensor([288.8501,  74.5112, 378.9531, 273.2818])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(145.)
#     coords:  tensor([  0.0000, 150.2149,  30.7693, 227.8001])
# last known:  tensor([288.8501,  74.5112, 378.9531, 273.2818])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(143.)
#     coords:  tensor([ 88.9585,   1.1418, 326.6150, 303.0176])
# last known:  tensor([288.8501,  74.5112, 378.9531, 273.2818])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(145.)
#     coords:  tensor([  0.0000, 151.3020,  28.4705, 248.3665])
# last known:  tensor([288.8501,  74.5112, 378.9531, 273.2818])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(146.)
#     coords:  tensor([544.9174, 179.9274, 585.3840, 255.8464])
# last known:  tensor([288.8501,  74.5112, 378.9531, 273.2818])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(102.)
#     coords:  tensor([308.9099,  80.7649, 373.5060, 264.7658])
# last known:  tensor([288.8501,  74.5112, 378.9531, 273.2818])
# [tensor(True), tensor(True), tensor(True), tensor(True)]
# 4
#
# 2455.5278
# 2468.7227orward
# 2530.8806orward
# 2303.5735orward
# 2092.7856orward
# 1939.4933orward
# 1854.1561
# new box id: tensor(157.)
#     coords:  tensor([442.5250,  67.4654, 534.8143, 154.0652])
# last known:  tensor([276.7332,  38.3665, 390.3891, 268.8178])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(102.)
#     coords:  tensor([274.0944,  39.7440, 388.2876, 271.0404])
# last known:  tensor([276.7332,  38.3665, 390.3891, 268.8178])
# [tensor(True), tensor(True), tensor(True), tensor(True)]
# 4
#
# 1905.7904
# new box id: tensor(102.)
#     coords:  tensor([282.7799,  34.1095, 415.9247, 273.1242])
# last known:  tensor([273.6123,  39.9272, 387.7953, 271.0987])
# [tensor(True), tensor(True), tensor(True), tensor(True)]
# 4
#
# 1917.9067
# 1672.2802
# 1559.2815
# 1321.895
# 1272.7395ight
# 1362.3645ack
# 1474.8247ack
# 1601.1661ack
# 1791.5336
# 1980.8646
# 1726.4594
# 1750.939
# 1738.174
# 1739.0222
# 1734.088
# 1739.077
# 1777.5419
# 1778.6044
# 1767.1943
# 1759.2793
# 1798.542
# 1786.745
# 1806.1569
# 1726.103
# 1767.8223
# 1760.2498
# 1749.4921
# 1775.5059
# 1812.398
# 1768.359
# 1745.9156
# 1737.9409
# 1740.8805
# 1762.4923
# 1742.8466
# 1739.0332
# 1739.8618
# 1770.023
# 1729.803
# 1740.7467
# 1747.3904
# 1783.0238
# 1766.9043
# 1775.8564
# 1772.9417
# 1769.9371
# 1722.8667
# 1748.3878
# 1759.3097
# 1740.149
# 1751.4165
# 1753.5629
# 1731.0508
# 1740.4537
# 1745.1469
# 1748.246
# 1759.1055
# 1770.9764
# 1763.2747
# 1766.3988
# 1759.128
# 1737.1868
# 1732.593
# 1753.7285
# 1733.6884
# 1736.4331
# 1754.4124
# 1746.6931
# 1756.1208
# 1756.9326
# 1756.4808
# 1749.0498
# 1775.3322
# 1762.2137
# 1757.469
# 1738.7733
# 1749.0259
# 1764.7505
# 1764.0815
# 1772.5603
# 1770.5297
# 1799.1404
# 1737.4462
# 1723.4786
# 1738.1807
# 1739.3187
# 1757.616
# 1732.0002
# 1772.5244
# 1779.6635
# 1790.9393
# 1792.8458
# 1789.6118
# 1774.7621
# 1788.9202
# 1765.4395
# 1728.3726
# 1740.4794
# 1712.1407
# 1711.2555
# 1683.5211
# 1721.7095
# 1717.117
# 1694.7595
# 1712.8042
# 1740.9402
# 1821.0156
# 1788.1232
# 1782.7744
# 1765.8601
# 1757.0114
# 1744.0201
# 1757.9832
# 1734.0883
# 1716.5055
# 1716.411
# 1718.7156
# 1755.6989
# 1766.1106
# 1746.1285
# 1772.4945
# 1745.6832
# 1731.2126
# 1709.4952
# 1756.9211
# 1761.9723
# 1726.2444
# 1712.3604
# 1707.3073
# 1706.8729
# 1709.9148
# 1715.9696
# 1707.6932
# 1717.6029
# 1700.3864
# 1706.0621
# 1706.6678
# 1710.6803
# 1729.1753
# 1718.6449
# 1741.424
# 1749.9454
# 1733.2806
# 1788.4688
# 1757.1372
# 1766.1838
# 2056.8716
# nanning forward
# 1734.7399
# 1623.0098
# 1631.7891
# 1604.6731
# 1622.991
# 1652.2977
# 1665.1019
# 1650.7178
# 1674.2981
# 1682.2559
# 1685.2651
# 1682.8416
# 1709.132
# 1694.0122
# 1661.9619
# 1655.8025
# 1679.1427
# 1683.3109
# 1615.2372
# 1647.2997
# 1705.4901
# nanpping
# 1697.0537
# 1711.696
# nanpping
# 1606.2183
# 1624.9635
# 1609.124
# 1688.7573
# 1692.6898
# 1617.2537
# 1661.5889
# 1650.8613
# 1625.7296
# nanpping
# nanpping
# 1763.403
# 1740.5372
# nanpping
# nanpping
# 1664.6637
# 1627.1759
# 1703.1755
# 8180.9165
# 827.1715forward
# nanning back
# 1588.0507
# 1589.5746
# 1610.9929
# 1634.6216
# 1363.9938
# 1253.9333ack
# 1185.5948ack
# 1225.6586ack
# 1080.5103ack
# 1076.3385ack
# 1340.2926ack
# 1608.515back
# 1752.7992
# 1801.6289
# 1747.1155
# 1532.2167
# 1329.3605
# 1142.4344ack
# 1063.4822ack
# 1050.9342ack
# 1195.964back
# 1327.1526ack
# new box id: tensor(278.)
#     coords:  tensor([409.9402, 159.1289, 471.0023, 255.1446])
# last known:  tensor([299.2120,   1.8684, 414.6828, 286.0645])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(102.)
#     coords:  tensor([3.0707e+02, 1.8656e-01, 4.1845e+02, 2.8743e+02])
# last known:  tensor([299.2120,   1.8684, 414.6828, 286.0645])
# [tensor(True), tensor(True), tensor(True), tensor(True)]
# 4
#
# 1314.837
# 1158.3032ack
# 1052.3838ack
# 1012.5356ack
# 1041.6282ack
# 1150.0604ack
# 1312.7233ack
# 1586.3567ack
# 1890.054
# new box id: tensor(301.)
#     coords:  tensor([301.3480,  59.8363, 380.1843, 144.5772])
# last known:  tensor([302.0065,  35.9241, 390.2826, 281.9195])
# [tensor(True), tensor(True), tensor(True), tensor(False)]
# 3
#
# 2173.6367
# new box id: tensor(306.)
#     coords:  tensor([382.2970, 177.7032, 413.7293, 250.7527])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(311.)
#     coords:  tensor([297.6133, 180.8187, 318.9501, 256.0050])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(312.)
#     coords:  tensor([ 42.6287, 152.4752, 101.7045, 231.6116])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(311.)
#     coords:  tensor([297.5509, 180.2914, 318.1991, 255.4202])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(312.)
#     coords:  tensor([ 49.4361, 154.9490, 106.0864, 231.8692])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(315.)
#     coords:  tensor([ 28.3603, 171.9674,  55.0111, 229.5487])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(311.)
#     coords:  tensor([296.9179, 179.4277, 316.5944, 255.7565])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(312.)
#     coords:  tensor([ 53.8087, 157.9943, 104.2693, 232.7682])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(312.)
#     coords:  tensor([ 56.0282, 160.4156, 102.5465, 233.7466])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(312.)
#     coords:  tensor([ 60.0357, 162.8240, 111.0153, 237.7566])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(312.)
#     coords:  tensor([ 66.9194, 158.6872, 121.9393, 240.2286])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(322.)
#     coords:  tensor([204.6235, 161.0503, 242.4055, 203.7865])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(312.)
#     coords:  tensor([ 76.5710, 160.3888, 129.0410, 239.5231])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(323.)
#     coords:  tensor([178.3726, 101.0705, 262.1840, 264.7023])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(312.)
#     coords:  tensor([ 82.5024, 168.1865, 133.2288, 241.1818])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(323.)
#     coords:  tensor([142.0607,  96.9835, 241.2101, 270.9075])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(325.)
#     coords:  tensor([ 84.7091, 169.4810, 132.2136, 215.4912])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(324.)
#     coords:  tensor([205.7698, 162.5222, 254.7618, 259.1896])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(323.)
#     coords:  tensor([120.3821,  92.3763, 221.5441, 271.5020])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(325.)
#     coords:  tensor([ 88.0790, 178.9459, 137.2275, 217.0560])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(324.)
#     coords:  tensor([205.0352, 163.0148, 256.6223, 257.9867])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(323.)
#     coords:  tensor([ 99.4803,  84.6297, 207.7440, 272.3371])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(324.)
#     coords:  tensor([205.0891, 162.9629, 256.6329, 257.1719])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(323.)
#     coords:  tensor([ 59.3217,  77.4593, 198.5063, 273.6084])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(324.)
#     coords:  tensor([204.7983, 162.9730, 256.3918, 256.7973])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(311.)
#     coords:  tensor([295.2085, 177.6462, 313.4992, 260.7089])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(323.)
#     coords:  tensor([ 40.1245,  73.0504, 180.0405, 273.6592])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(324.)
#     coords:  tensor([204.4895, 163.1305, 256.0559, 257.1435])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(311.)
#     coords:  tensor([295.3822, 179.4037, 314.2445, 257.5007])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(323.)
#     coords:  tensor([ 37.7462,  70.9058, 165.1481, 274.8684])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(324.)
#     coords:  tensor([204.0685, 162.9947, 255.8635, 257.3257])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(331.)
#     coords:  tensor([ 61.9396,  71.4114, 165.3348, 152.1840])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(323.)
#     coords:  tensor([ 41.4199,  71.0594, 161.3013, 274.1433])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(324.)
#     coords:  tensor([204.6396, 162.8112, 255.8952, 256.8743])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(331.)
#     coords:  tensor([ 60.9902,  72.0601, 164.0940, 151.2722])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(332.)
#     coords:  tensor([379.8989, 178.8831, 406.2814, 253.1669])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(323.)
#     coords:  tensor([ 43.6418,  71.8500, 161.3454, 273.2601])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(324.)
#     coords:  tensor([204.4286, 162.4746, 255.7668, 255.7510])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(332.)
#     coords:  tensor([381.2709, 179.4553, 405.0386, 251.1698])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(323.)
#     coords:  tensor([ 45.3559,  72.2733, 162.1455, 273.6712])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(324.)
#     coords:  tensor([204.1781, 162.2843, 255.8391, 256.2728])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(332.)
#     coords:  tensor([384.7302, 177.8440, 405.7792, 253.3065])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(323.)
#     coords:  tensor([ 47.0202,  72.8736, 162.9584, 274.0354])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(324.)
#     coords:  tensor([204.1218, 162.3842, 255.6043, 257.3416])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(332.)
#     coords:  tensor([383.9712, 176.6172, 404.4471, 272.4749])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(323.)
#     coords:  tensor([ 47.2514,  73.6183, 163.3440, 274.4207])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(324.)
#     coords:  tensor([204.3541, 162.5472, 255.5392, 258.0351])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(311.)
#     coords:  tensor([292.4492, 161.1781, 322.6885, 255.1335])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(323.)
#     coords:  tensor([ 46.9514,  74.5593, 163.5942, 273.8260])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(324.)
#     coords:  tensor([204.4284, 162.5194, 255.7094, 256.9808])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(311.)
#     coords:  tensor([292.8498, 164.1726, 323.8992, 255.0942])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(323.)
#     coords:  tensor([ 45.7993,  75.5898, 164.4883, 273.3326])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(324.)
#     coords:  tensor([204.2209, 162.8346, 255.7375, 256.5596])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(311.)
#     coords:  tensor([292.4418, 167.8883, 325.4358, 255.0780])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(323.)
#     coords:  tensor([ 45.6465,  75.2625, 164.6129, 273.7039])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(324.)
#     coords:  tensor([204.2626, 162.8113, 255.8989, 256.9572])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(311.)
#     coords:  tensor([295.2719, 172.5897, 327.3515, 255.6037])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(323.)
#     coords:  tensor([ 47.1774,  76.2205, 180.2833, 272.5009])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(324.)
#     coords:  tensor([204.0899, 162.7949, 255.8257, 256.3695])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(311.)
#     coords:  tensor([297.1695, 178.2855, 324.8960, 255.9088])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(324.)
#     coords:  tensor([203.8715, 162.6207, 255.5733, 257.0093])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(311.)
#     coords:  tensor([297.6005, 181.3920, 323.0530, 256.3250])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(324.)
#     coords:  tensor([203.8936, 162.6865, 255.6491, 257.2753])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(311.)
#     coords:  tensor([298.2604, 181.4817, 324.1970, 256.1639])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(330.)
#     coords:  tensor([129.7422,  89.7756, 203.5491, 159.6838])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(324.)
#     coords:  tensor([206.7450, 163.2097, 255.4302, 245.7457])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(311.)
#     coords:  tensor([298.3211, 181.2810, 323.4678, 255.6341])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(343.)
#     coords:  tensor([374.0937, 176.4411, 424.3289, 260.0075])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(311.)
#     coords:  tensor([298.2358, 181.2073, 324.3413, 255.9904])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(343.)
#     coords:  tensor([377.3441, 176.8885, 420.5936, 259.1048])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(341.)
#     coords:  tensor([380.1866, 177.7327, 404.9047, 252.9974])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(311.)
#     coords:  tensor([298.3615, 181.7186, 323.8354, 255.0284])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(343.)
#     coords:  tensor([379.7095, 180.0017, 414.6952, 255.9052])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(341.)
#     coords:  tensor([380.1626, 177.9648, 404.6310, 254.5330])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(349.)
#     coords:  tensor([395.6436, 185.8861, 422.1522, 252.4272])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(311.)
#     coords:  tensor([298.3130, 181.5321, 322.5086, 255.2810])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(343.)
#     coords:  tensor([378.3715, 178.4441, 412.4857, 257.4146])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(341.)
#     coords:  tensor([380.1118, 177.8045, 403.9877, 254.6522])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(349.)
#     coords:  tensor([396.2321, 186.0329, 422.1325, 252.5235])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(351.)
#     coords:  tensor([231.6348,  83.6759, 306.7036, 269.7474])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(352.)
#     coords:  tensor([379.8177, 181.2617, 423.4562, 258.7411])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(324.)
#     coords:  tensor([205.2242, 161.7763, 256.1041, 252.7408])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(343.)
#     coords:  tensor([379.0545, 177.4557, 414.5077, 258.0597])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(341.)
#     coords:  tensor([380.4302, 177.9839, 404.5274, 254.4391])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(349.)
#     coords:  tensor([396.1905, 186.1982, 421.6118, 251.5119])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(351.)
#     coords:  tensor([252.0553,  82.1371, 327.8253, 272.4254])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(True), tensor(False), tensor(False)]
# 2
#
# new box id: tensor(353.)
#     coords:  tensor([136.7779, 137.5047, 189.8262, 266.8888])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(324.)
#     coords:  tensor([204.7132, 162.2564, 255.7039, 254.2701])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(343.)
#     coords:  tensor([379.6794, 177.4371, 416.5086, 257.0278])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(341.)
#     coords:  tensor([380.6157, 178.3848, 405.2600, 254.0592])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(349.)
#     coords:  tensor([396.5283, 186.3848, 421.5739, 250.7057])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(351.)
#     coords:  tensor([265.0326,  68.3456, 344.2783, 272.8622])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(True), tensor(True), tensor(False)]
# 3
#
# new box id: tensor(353.)
#     coords:  tensor([137.6949, 136.7169, 189.2799, 266.3377])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(324.)
#     coords:  tensor([204.7354, 162.6827, 255.5877, 255.5526])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(343.)
#     coords:  tensor([379.5339, 177.4213, 416.0987, 257.4287])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(341.)
#     coords:  tensor([380.5621, 178.6655, 405.1931, 254.2336])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(349.)
#     coords:  tensor([397.2531, 186.5017, 421.1704, 249.1954])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(351.)
#     coords:  tensor([276.9837,  60.7320, 357.9228, 273.8506])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(True), tensor(True), tensor(False)]
# 3
#
# new box id: tensor(353.)
#     coords:  tensor([137.8250, 136.7555, 189.0267, 266.7350])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(324.)
#     coords:  tensor([204.9223, 162.5340, 255.9153, 256.5481])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(343.)
#     coords:  tensor([379.0567, 177.5980, 415.9913, 257.0223])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(341.)
#     coords:  tensor([380.4962, 178.6710, 405.4791, 253.9586])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(349.)
#     coords:  tensor([398.1151, 186.6570, 421.0085, 248.2675])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(351.)
#     coords:  tensor([285.0478,  53.6832, 370.2499, 275.3254])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(True), tensor(True), tensor(False)]
# 3
#
# new box id: tensor(353.)
#     coords:  tensor([138.4401, 136.8275, 189.3958, 266.9476])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(324.)
#     coords:  tensor([204.7511, 162.2772, 256.0695, 255.3066])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(343.)
#     coords:  tensor([378.1710, 178.2975, 419.6133, 257.0710])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(341.)
#     coords:  tensor([380.3502, 178.4228, 407.2162, 254.1143])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(349.)
#     coords:  tensor([398.2437, 186.7194, 421.1347, 248.3087])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(351.)
#     coords:  tensor([285.5102,  41.4965, 381.7221, 279.1451])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(True), tensor(True), tensor(False)]
# 3
#
# new box id: tensor(353.)
#     coords:  tensor([136.9838, 137.5007, 189.0755, 267.3195])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(324.)
#     coords:  tensor([204.8554, 162.2445, 256.2029, 257.0017])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(343.)
#     coords:  tensor([378.7410, 178.1931, 421.1237, 259.0786])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(341.)
#     coords:  tensor([380.1999, 178.6582, 406.2489, 255.1727])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(349.)
#     coords:  tensor([398.9902, 187.1111, 421.6908, 249.7368])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(351.)
#     coords:  tensor([284.4731,  23.0271, 388.7388, 281.0175])
# last known:  tensor([300.7960,  64.4561, 378.6368, 146.3525])
# [tensor(True), tensor(True), tensor(True), tensor(False)]
# 3
#
# 1604.7858
# 1427.2957
# 1326.6241ack
# 1409.1416ack
# 1538.6952ack
# 1786.592
# 1927.0813
# 2109.1472
# 2191.8533orward
# 2323.6516orward
# 2349.683forward
# 2506.8794orward
# 2479.602forward
# 2407.768forward
# 2375.137forward
# 2487.027forward
# 1718.0532orward
# 1633.2367
# 1657.9689
# 1631.8794
# 1650.3944
# new box id: tensor(387.)
#     coords:  tensor([401.7791, 175.8043, 422.1599, 250.2432])
# last known:  tensor([273.7896,  43.2645, 374.1418, 276.8582])
# [tensor(False), tensor(False), tensor(True), tensor(True)]
# 2
#
# new box id: tensor(387.)
#     coords:  tensor([401.0978, 175.5286, 424.4765, 256.2073])
# last known:  tensor([273.7896,  43.2645, 374.1418, 276.8582])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(387.)
#     coords:  tensor([401.2391, 174.9928, 424.3251, 256.1443])
# last known:  tensor([273.7896,  43.2645, 374.1418, 276.8582])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(389.)
#     coords:  tensor([275.6077, 175.8263, 300.1193, 255.1863])
# last known:  tensor([273.7896,  43.2645, 374.1418, 276.8582])
# [tensor(True), tensor(False), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(389.)
#     coords:  tensor([274.5392, 175.5228, 294.7354, 257.1070])
# last known:  tensor([273.7896,  43.2645, 374.1418, 276.8582])
# [tensor(True), tensor(False), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(390.)
#     coords:  tensor([186.7129, 181.0639, 222.3381, 259.8261])
# last known:  tensor([273.7896,  43.2645, 374.1418, 276.8582])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(351.)
#     coords:  tensor([283.8857,   0.5066, 382.4548, 292.2527])
# last known:  tensor([273.7896,  43.2645, 374.1418, 276.8582])
# [tensor(True), tensor(True), tensor(True), tensor(True)]
# 4
#
# 1148.0787
# 1508.0883ack
# 1895.0532
# 2072.144
# 2130.1309orward
# 2092.75 forward
# 1872.36 forward
# 1772.9896
# 1812.0054
# 1872.8921
# new box id: tensor(351.)
#     coords:  tensor([293.0536,  86.0801, 357.4034, 269.5565])
# last known:  tensor([302.4480,  71.9678, 393.7494, 270.0761])
# [tensor(True), tensor(True), tensor(True), tensor(True)]
# 4
#
# 2131.0955
# 2213.5293orward
# 2043.6154orward
# 1652.0176orward
# 1461.5057
# 1383.5391ack
# 1466.1796ack
# 1797.9548ight
# 1745.9044
# 1762.5917
# 1728.5593
# 1722.6503
# 1403.4357
# 1334.3287ack
# 1250.4048ack
# 1322.5746ack
# 1355.3389ack
# 1377.8313ack
# 1353.235left
# new box id: tensor(437.)
#     coords:  tensor([229.8514, 197.3268, 254.8292, 273.3204])
# last known:  tensor([219.8267,  34.6492, 349.9793, 286.0071])
# [tensor(True), tensor(False), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(438.)
#     coords:  tensor([346.0364, 181.2103, 389.4793, 262.2933])
# last known:  tensor([219.8267,  34.6492, 349.9793, 286.0071])
# [tensor(False), tensor(False), tensor(True), tensor(True)]
# 2
#
# new box id: tensor(351.)
#     coords:  tensor([231.3594,  61.7316, 347.7352, 284.0152])
# last known:  tensor([219.8267,  34.6492, 349.9793, 286.0071])
# [tensor(True), tensor(True), tensor(True), tensor(True)]
# 4
#
# 1559.3967
# new box id: tensor(439.)
#     coords:  tensor([415.7258, 172.4227, 465.8824, 257.4042])
# last known:  tensor([199.7914,  65.8676, 319.4678, 281.9235])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(445.)
#     coords:  tensor([129.2648, 116.1253, 218.0902, 270.3819])
# last known:  tensor([199.7914,  65.8676, 319.4678, 281.9235])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(439.)
#     coords:  tensor([415.0397, 172.8932, 466.1630, 257.6459])
# last known:  tensor([199.7914,  65.8676, 319.4678, 281.9235])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(445.)
#     coords:  tensor([130.0895, 116.1471, 219.0712, 272.1992])
# last known:  tensor([199.7914,  65.8676, 319.4678, 281.9235])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(439.)
#     coords:  tensor([414.7567, 173.7684, 466.9593, 257.3284])
# last known:  tensor([199.7914,  65.8676, 319.4678, 281.9235])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# ...
# 2
#
# new box id: tensor(851.)
#     coords:  tensor([182.5089, 214.2640, 201.4363, 235.6403])
# last known:  tensor([320.1390,  72.4215, 399.2717, 271.6960])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(832.)
#     coords:  tensor([367.1881,  72.7582, 474.0537, 273.7137])
# last known:  tensor([320.1390,  72.4215, 399.2717, 271.6960])
# [tensor(True), tensor(True), tensor(False), tensor(True)]
# 3
#
# 1898.9641
# 1783.2023
# 1737.5289
# 1668.0981
# 1642.2444
# 1694.1544
# 1812.4393
# 1868.8215
# 2058.557
# 2027.9531orward
# 1672.3322orward
# nanpping
# nanpping
# new box id: tensor(880.)
#     coords:  tensor([200.2479, 252.7571, 221.9781, 289.1086])
# last known:  tensor([286.9596,   3.7449, 407.4101, 291.0279])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(880.)
#     coords:  tensor([200.4676, 247.2256, 225.0061, 283.8806])
# last known:  tensor([286.9596,   3.7449, 407.4101, 291.0279])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(880.)
#     coords:  tensor([203.1062, 230.2993, 227.9441, 265.8935])
# last known:  tensor([286.9596,   3.7449, 407.4101, 291.0279])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(880.)
#     coords:  tensor([203.4304, 229.6764, 228.4488, 264.3094])
# last known:  tensor([286.9596,   3.7449, 407.4101, 291.0279])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(880.)
#     coords:  tensor([202.8853, 229.8916, 226.7993, 263.6991])
# last known:  tensor([286.9596,   3.7449, 407.4101, 291.0279])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(894.)
#     coords:  tensor([161.9263, 253.7252, 176.2094, 277.0747])
# last known:  tensor([286.9596,   3.7449, 407.4101, 291.0279])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(880.)
#     coords:  tensor([203.2604, 229.6908, 230.5286, 263.3197])
# last known:  tensor([286.9596,   3.7449, 407.4101, 291.0279])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(894.)
#     coords:  tensor([160.7557, 257.2925, 176.8421, 276.7185])
# last known:  tensor([286.9596,   3.7449, 407.4101, 291.0279])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(880.)
#     coords:  tensor([203.3309, 229.7660, 231.2809, 263.1810])
# last known:  tensor([286.9596,   3.7449, 407.4101, 291.0279])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(832.)
#     coords:  tensor([307.5271,  28.2415, 438.5901, 331.2177])
# last known:  tensor([286.9596,   3.7449, 407.4101, 291.0279])
# [tensor(True), tensor(True), tensor(True), tensor(True)]
# 4
#
# 1151.671
# 1553.9111ack
# 1805.0654
# 1826.602
# new box id: tensor(903.)
#     coords:  tensor([206.4024, 231.9118, 227.5843, 259.5669])
# last known:  tensor([317.1119,  94.6950, 396.0685, 311.7808])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(832.)
#     coords:  tensor([312.9571,  87.3021, 408.5998, 319.2253])
# last known:  tensor([317.1119,  94.6950, 396.0685, 311.7808])
# [tensor(True), tensor(True), tensor(True), tensor(True)]
# 4
#
# 1793.878
# 1501.9299
# 1267.8893
# 1083.4691ack
# new box id: tensor(907.)
#     coords:  tensor([  1.5616,  15.1741, 144.1560, 349.7998])
# last known:  tensor([281.7870,  13.7353, 415.4390, 337.1955])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(907.)
#     coords:  tensor([  0.0000,   0.0000, 163.7093, 342.4452])
# last known:  tensor([281.7870,  13.7353, 415.4390, 337.1955])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(907.)
#     coords:  tensor([  0.0000,   0.0000, 169.8950, 339.2965])
# last known:  tensor([281.7870,  13.7353, 415.4390, 337.1955])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(832.)
#     coords:  tensor([2.2973e+02, 3.5492e-01, 5.1762e+02, 3.6806e+02])
# last known:  tensor([281.7870,  13.7353, 415.4390, 337.1955])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(907.)
#     coords:  tensor([1.7764e-01, 0.0000e+00, 1.7633e+02, 3.2744e+02])
# last known:  tensor([281.7870,  13.7353, 415.4390, 337.1955])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(832.)
#     coords:  tensor([1.0967e+02, 1.4687e-01, 6.1530e+02, 3.7175e+02])
# last known:  tensor([281.7870,  13.7353, 415.4390, 337.1955])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(907.)
#     coords:  tensor([1.8623e-02, 0.0000e+00, 1.8437e+02, 3.2418e+02])
# last known:  tensor([281.7870,  13.7353, 415.4390, 337.1955])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(907.)
#     coords:  tensor([3.0017e-01, 0.0000e+00, 1.8994e+02, 3.2991e+02])
# last known:  tensor([281.7870,  13.7353, 415.4390, 337.1955])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(911.)
#     coords:  tensor([128.4555, 214.9749, 168.4752, 260.3482])
# last known:  tensor([281.7870,  13.7353, 415.4390, 337.1955])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(907.)
#     coords:  tensor([  0.0000,   0.0000, 190.2574, 332.6673])
# last known:  tensor([281.7870,  13.7353, 415.4390, 337.1955])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(911.)
#     coords:  tensor([126.6111, 212.6518, 167.0885, 262.2471])
# last known:  tensor([281.7870,  13.7353, 415.4390, 337.1955])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(912.)
#     coords:  tensor([240.0897, 228.6914, 273.9641, 265.1008])
# last known:  tensor([281.7870,  13.7353, 415.4390, 337.1955])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(910.)
#     coords:  tensor([473.9786, 211.8961, 499.9690, 255.7093])
# last known:  tensor([281.7870,  13.7353, 415.4390, 337.1955])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(907.)
#     coords:  tensor([6.8792e-02, 0.0000e+00, 1.8618e+02, 3.3627e+02])
# last known:  tensor([281.7870,  13.7353, 415.4390, 337.1955])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(911.)
#     coords:  tensor([124.0320, 213.8438, 166.1201, 262.8603])
# last known:  tensor([281.7870,  13.7353, 415.4390, 337.1955])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(912.)
#     coords:  tensor([241.3047, 231.4218, 273.9066, 266.5432])
# last known:  tensor([281.7870,  13.7353, 415.4390, 337.1955])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(913.)
#     coords:  tensor([274.8165,   2.3080, 443.7908, 331.7225])
# last known:  tensor([281.7870,  13.7353, 415.4390, 337.1955])
# [tensor(True), tensor(True), tensor(True), tensor(True)]
# 4
#
# 1135.7494
# 1479.7018ack
# 1791.9697ack
# 1980.7365
# 2056.815
# new box id: tensor(913.)
#     coords:  tensor([314.8222,  98.3410, 392.3534, 308.6259])
# last known:  tensor([316.0834, 107.0346, 379.1991, 304.1959])
# [tensor(True), tensor(True), tensor(True), tensor(True)]
# 4
#
# 1898.5339
# 1648.0378
# 1551.9395
# 1369.9963
# 1283.3342ack
# 1398.8689ack
# 1497.5184ack
# 1583.0494ack
# 1658.3322
# 1373.7823
# 1143.6304ack
# 1074.3887ack
# new box id: tensor(933.)
#     coords:  tensor([233.6973, 217.4961, 256.7985, 259.1280])
# last known:  tensor([278.8314,   4.6044, 417.0287, 330.5177])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(913.)
#     coords:  tensor([299.5999,  11.0869, 431.3180, 328.9410])
# last known:  tensor([278.8314,   4.6044, 417.0287, 330.5177])
# [tensor(True), tensor(True), tensor(True), tensor(True)]
# 4
#
# 1100.1757
# 1177.2089ack
# 1366.0859ight
# 1427.2418ack
# 1443.2836ack
# 1644.1903ack
# 2359.3616
# nanning forward
# new box id: tensor(962.)
#     coords:  tensor([453.9257, 178.5969, 533.9099, 280.0657])
# last known:  tensor([374.0842, 102.4014, 431.1815, 291.0262])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(964.)
#     coords:  tensor([476.1089, 178.0465, 535.4006, 275.5462])
# last known:  tensor([374.0842, 102.4014, 431.1815, 291.0262])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(965.)
#     coords:  tensor([161.6826,  40.0186, 436.1496, 322.2419])
# last known:  tensor([374.0842, 102.4014, 431.1815, 291.0262])
# [tensor(False), tensor(False), tensor(True), tensor(True)]
# 2
#
# new box id: tensor(913.)
#     coords:  tensor([371.9505,  97.6486, 442.4455, 266.1618])
# last known:  tensor([374.0842, 102.4014, 431.1815, 291.0262])
# [tensor(True), tensor(True), tensor(True), tensor(True)]
# 4
#
# 2182.5903
# 1970.8727orward
# 1783.524right
# 1847.324
# 1676.7386
# 1633.7141
# 1591.6051
# 1590.2366
# 1586.995
# 1578.8988
# 1562.2969
# 1570.1405
# 1572.5332
# 1572.7393
# 1573.8214
# 1560.9171
# 1565.1016
# 1581.4553
# 1586.712
# 1574.176
# 1586.939
# 1578.0476
# 1569.5509
# 1563.1927
# 1563.3398
# 1570.2026
# 1590.6802
# 1579.0027
# 1570.452
# 1577.5452
# 1583.4194
# 1583.3053
# 1577.4718
# 1570.4281
# 1565.6111
# 1567.2687
# 1572.2769
# 1581.1072
# 1585.4315
# 1577.7347
# 1581.085
# 1584.9174
# 1605.8188
# 1611.7391
# 1624.3595
# 1648.7194
# 1791.4674
# 1879.1079
# 1904.5166
# 2018.5367
# 2052.9998orward
# 1955.6017orward
# 1879.6932
# 1881.9991
# 1898.7852
# 1897.2842
# 1928.6556
# 1914.778
# 1861.7006
# new box id: tensor(1024.)
#     coords:  tensor([326.9236,  10.1563, 490.2962, 371.3496])
# last known:  tensor([331.8278,  65.6560, 403.4588, 257.9345])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(1024.)
#     coords:  tensor([330.0015,   0.0000, 549.7694, 371.4247])
# last known:  tensor([331.8278,  65.6560, 403.4588, 257.9345])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(1024.)
#     coords:  tensor([376.5475,   0.0000, 591.0104, 348.2572])
# last known:  tensor([331.8278,  65.6560, 403.4588, 257.9345])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(913.)
#     coords:  tensor([327.3969,  64.8435, 405.8330, 298.5184])
# last known:  tensor([331.8278,  65.6560, 403.4588, 257.9345])
# [tensor(True), tensor(True), tensor(True), tensor(True)]
# 4
#
# 1928.7305
# 1912.7299
# 1900.3539
# 1881.219
# 1893.3949
# 1945.0438
# 1967.1102
# 1952.3438
# 1947.6753
# 1949.2063
# 1925.5583
# 1903.9525
# 1927.3668eft
# 1762.5195
# 1849.6925
# 2145.991right
# 2107.7688orward
# 2082.9873orward
# 2011.305forward
# 1878.1549orward
# 1706.028
# 1707.4886
# 1724.133
# 1733.2217
# 1740.8219
# 1727.1705
# 1714.4133
# 1739.3706
# 1898.3943
# 2020.8091
# 2083.7034orward
# 2089.4697orward
# 1979.9688orward
# 1908.1456
# 1900.4186
# 1901.6022
# 1913.7249
# 1925.7002
# 1879.9912
# 1876.0488eft
# 1851.2902
# 2029.8976
# 2061.703forward
# 1933.858forward
# 1693.6138
# 1822.2056
# 1825.5792
# 1784.0266
# 1907.6377
# 1989.5732
# 2053.9084
# 2027.3182ight
# 1919.9685orward
# 1947.6211
# 2380.575left
# 3476.3982orward
# 3925.302forward
# 4358.7188orward
# 4814.473forward
# 5266.622forward
# 5422.39 forward
# new box id: tensor(1133.)
#     coords:  tensor([265.4748, 202.6229, 292.0887, 277.1132])
# last known:  tensor([273.4495, 208.1172, 298.5674, 282.4924])
# [tensor(True), tensor(True), tensor(True), tensor(True)]
# 4
#
# 4768.0967
# 5100.7085orward
# 5430.8794orward
# 5191.967forward
# new box id: tensor(1142.)
#     coords:  tensor([ 45.0969, 177.6317, 109.8649, 251.4266])
# last known:  tensor([271.2207, 195.7892, 298.7634, 281.4314])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(1142.)
#     coords:  tensor([ 27.4361, 171.5433,  93.7368, 252.3721])
# last known:  tensor([271.2207, 195.7892, 298.7634, 281.4314])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(1142.)
#     coords:  tensor([ 14.9558, 181.8053,  83.8815, 253.1827])
# last known:  tensor([271.2207, 195.7892, 298.7634, 281.4314])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(1133.)
#     coords:  tensor([258.1342, 195.8089, 290.2265, 280.5114])
# last known:  tensor([271.2207, 195.7892, 298.7634, 281.4314])
# [tensor(True), tensor(True), tensor(True), tensor(True)]
# 4
#
# 4974.408left
# 5372.7505orward
# 4688.7266orward
# 4437.566forward
# 4091.0403orward
# 3735.3362orward
# 3298.7717orward
# 2962.487forward
# 2674.0383orward
# 2264.4875orward
# 1705.0234orward
# 1346.1562
# nanning back
# 430.41568
# new box id: tensor(1160.)
#     coords:  tensor([341.8022,   3.8963, 660.0145, 367.3562])
# last known:  tensor([241.5661,   6.4407, 432.1645, 346.5450])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(1160.)
#     coords:  tensor([368.3835,   0.0000, 663.6841, 370.3111])
# last known:  tensor([241.5661,   6.4407, 432.1645, 346.5450])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(1165.)
#     coords:  tensor([ 31.6433, 230.3229,  60.7614, 249.3191])
# last known:  tensor([241.5661,   6.4407, 432.1645, 346.5450])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(1166.)
#     coords:  tensor([120.7304,   1.3978, 323.9474, 369.8015])
# last known:  tensor([241.5661,   6.4407, 432.1645, 346.5450])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(1166.)
#     coords:  tensor([161.5619,   1.8155, 394.0723, 370.3712])
# last known:  tensor([241.5661,   6.4407, 432.1645, 346.5450])
# [tensor(False), tensor(True), tensor(True), tensor(True)]
# 3
#
# nan
# nanpping
# 1147.0579
# 1553.8541ack
# 1995.7009
# 1976.0139
# 2354.509
# 2401.6746orward
# 2419.261forward
# 2396.7139orward
# 2516.9126orward
# 2778.0417orward
# new box id: tensor(1187.)
#     coords:  tensor([232.6354, 202.6808, 262.5015, 283.7599])
# last known:  tensor([299.5887, 133.6250, 371.1390, 288.7029])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(1166.)
#     coords:  tensor([288.9920, 134.8176, 345.2287, 286.5919])
# last known:  tensor([299.5887, 133.6250, 371.1390, 288.7029])
# [tensor(True), tensor(True), tensor(True), tensor(True)]
# 4
#
# nan
# 2834.481
# 3126.7903orward
# 2921.8652orward
# 2788.6392orward
# 2814.3137orward
# 2590.8462orward
# 2418.6868orward
# 2370.165forward
# 2220.0364orward
# 2065.737forward
# 1948.5061orward
# 1811.801
# 1769.8856
# 1740.1093
# 1696.5127eft
# 1588.0306
# 1516.6012
# nanpping
# 1335.2968
# 1101.3331eft
# 1117.866back
# 1535.9623eft
# 1588.8466
# 1539.6274
# 1585.256
# 1928.6241eft
# 1275.1787ight
# 1288.0283ack
# 1430.7g back
# 1793.1377ight
# new box id: tensor(1274.)
#     coords:  tensor([425.0910, 201.4511, 458.5075, 281.1082])
# last known:  tensor([320.4817,  67.1579, 406.5025, 305.7286])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(1166.)
#     coords:  tensor([308.7618,  96.9178, 409.4106, 294.4885])
# last known:  tensor([320.4817,  67.1579, 406.5025, 305.7286])
# [tensor(True), tensor(True), tensor(True), tensor(True)]
# 4
#
# 1930.8691
# 1991.096
# 2074.6614
# 2107.2974orward
# 2445.9397orward
# 3065.3018ight
# 3469.0662orward
# 3139.2751orward
# 3125.6772orward
# 3664.7776orward
# 3617.5962orward
# 3861.8748orward
# 3449.194forward
# 3342.4873orward
# 3217.7788orward
# 3147.091forward
# 2983.8g forward
# 2864.6438orward
# 2844.6812orward
# 2474.8005orward
# 2479.5137orward
# 2331.4758orward
# 2163.9631orward
# 2028.5673orward
# 1990.9653orward
# 2042.237left
# 2052.2488orward
# 2010.0317orward
# 1907.1138orward
# 1731.6621
# 1731.8254
# 1711.8191
# 1788.1772
# 2115.5376
# turning forward
