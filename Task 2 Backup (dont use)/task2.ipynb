# %%
import numpy as np
import ipywidgets.widgets as widgets
import time
from IPython.display import display
image_display = widgets.Image(format="jpeg", width="45%")
full_display = widgets.Image(format="jpeg", width="45%")
display(widgets.HBox([image_display, full_display]))

location_coords_display = widgets.Label()
display(location_coords_display)

import cv2
import pyzed.sl as sl
camera = sl.Camera()
camera_params = sl.InitParameters()
camera_params.camera_resolution = sl.RESOLUTION.VGA
camera_params.depth_mode = sl.DEPTH_MODE.ULTRA
camera_params.coordinate_units = sl.UNIT.MILLIMETER

camera_status = camera.open(camera_params)
if camera_status != sl.ERROR_CODE.SUCCESS:
    print("camera error")
    print(camera_status)
    camera.close()
    exit()

# initialize robot
import motors
robot = motors.MotorsYukon()
robot.stop()

# initialize model
import tracking
m = tracking.Model()

# get initial image and choose object to track
image_mat = sl.Mat()
depth_mat = sl.Mat()
started_tracking = False
while not started_tracking:
    err = camera.grab()
    if err == sl.ERROR_CODE.SUCCESS:
        camera.retrieve_image(image_mat)
        image = image_mat.get_data()
        
        image_display.value = m.show_all_boxes(image)
    
        user_input = input("enter id to track (or leave blank to skip):")
        if user_input == "":
            continue
        else:
            m.tracked_id = int(user_input)
            print("tracking object id " + str(user_input))
            started_tracking = True

# movement parameters
KEEP_X_BETWEEN = (275, 417)
TURN_SPEED = 0.3
TURN_SLEEP = 0.05
KEEP_DEPTH_BETWEEN = (750, 1250)
MOVE_SPEED = 0.5
MOVE_SLEEP = 0.05

# start tracking
running = True
while running:
    err = camera.grab()
    if err == sl.ERROR_CODE.SUCCESS:
        camera.retrieve_image(image_mat)
        image = image_mat.get_data()

        camera.retrieve_measure(depth_mat, measure=sl.MEASURE.DEPTH)
        depth = depth_mat.get_data()
        
        tracked_box = m.track(image, return_type="corners")
        
        if tracked_box is False:
            image_display.value = bytes(cv2.imencode('.jpg', image)[1])
            robot.stop()
        else:
            x_centre = int((tracked_box[0] + tracked_box[2]) / 2)
            y_centre = int((tracked_box[1] + tracked_box[3]) / 2)
            image_rect = cv2.rectangle(
                image,
                (int(tracked_box[0]), int(tracked_box[1])),
                (int(tracked_box[2]), int(tracked_box[3])),
                (255, 0, 0),
                4
            )
            image_display.value = bytes(cv2.imencode('.jpg', image_rect)[1])

            # turn if tracked person is outside KEEP_X_BETWEEN
            if x_centre < KEEP_X_BETWEEN[0]:
                robot.left(speed=TURN_SPEED)
                time.sleep(TURN_SLEEP)
                print("turning left   ", end="\r")
            elif x_centre > KEEP_X_BETWEEN[1]:
                robot.right(speed=TURN_SPEED)
                time.sleep(TURN_SLEEP)
                print("turning right  ", end="\r")
            else:
                # only correct distance if target is centred
                depth_value = depth[y_centre, x_centre]
                print(depth_value)
                if depth_value < KEEP_DEPTH_BETWEEN[0]:
                    robot.backward(speed=MOVE_SPEED)
                    time.sleep(MOVE_SLEEP)
                    print("turning back   ", end="\r")
                elif depth_value > KEEP_DEPTH_BETWEEN[1]:
                    robot.forward(speed=MOVE_SPEED)
                    time.sleep(MOVE_SLEEP)
                    print("turning forward", end="\r")
                else:
                    robot.stop()
                    print("stopping       ", end="\r")

        full_display.value = m.show_all_boxes(image)
    

camera.close()
# Out:
# HBox(children=(Image(value=b'', format='jpeg', width='45%'), Image(value=b'', format='jpeg', width='45%')))
# Label(value='')
# [2025-05-07 08:37:32 UTC][ZED][INFO] Logging level INFO
# [2025-05-07 08:37:32 UTC][ZED][INFO] Logging level INFO
# [2025-05-07 08:37:32 UTC][ZED][INFO] Logging level INFO
# [2025-05-07 08:37:33 UTC][ZED][INFO] [Init]  Depth mode: ULTRA
# [2025-05-07 08:37:34 UTC][ZED][INFO] [Init]  Camera successfully opened.
# [2025-05-07 08:37:34 UTC][ZED][INFO] [Init]  Camera FW version: 1523
# [2025-05-07 08:37:34 UTC][ZED][INFO] [Init]  Video mode: VGA@100
# [2025-05-07 08:37:34 UTC][ZED][INFO] [Init]  Serial Number: S/N 38559894
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Loading yolo11n.engine for TensorRT inference...
# [05/07/2025-09:37:39] [TRT] [I] Loaded engine size: 12 MiB
# [05/07/2025-09:37:39] [TRT] [W] Using an engine plan file across different models of devices is not recommended and is likely to affect performance or even cause errors.
# [05/07/2025-09:37:39] [TRT] [I] [MemUsageChange] TensorRT-managed allocation in IExecutionContext creation: CPU +0, GPU +18, now: CPU 0, GPU 28 (MiB)
# enter id to track (or leave blank to skip): 2
# tracking object id 2
# 1459.4795
# 1414.777forward
# 1118.3726orward
# 1037.7329
# 1049.0729
# 1078.8495
# 1110.1952
# nanpping
# nanpping
# 1036.1146eft
# nanpping
# 1005.456
# 848.2844
# 908.19446
# 881.5559
# 875.5593
# 881.42163
# 878.6243
# 882.22766
# 877.4361
# nanpping
# 974.0058left
# nanpping
# nanpping
# 1825.108
# 956.7066forward
# 976.5276left
# 926.931g
# 871.3802right
# 868.02997
# 1464.9944
# 891.28204ight
# nanpping
# 4622.6265
# 774.1025forward
# 737.8226right
# 525.57745ack
# nanning back
# nanpping
# 628.2897
# 726.56836ack
# nanning back
# nanpping
# 1342.7598
# nanning forward
# 1259.9983
# 1251.442forward
# 1122.1848orward
# 2091.4072
# 842.8548left
# 727.8277
# nanning back
# nanpping
# nanpping
# 831.7463left
# 1294.4166ight
# new box id: tensor(36.)
#     coords:  tensor([187.8112,   9.7858, 311.0752, 308.8964])
# last known:  tensor([109.9472,   6.7227, 342.4393, 305.0841])
# [tensor(False), tensor(True), tensor(True), tensor(True)]
# 3
#
# 700.02765eft
# 735.0141back
# 842.0469back
# 917.54675
# 904.24176
# nanpping
# 1142.1892
# 1268.5154eft
# 1090.0533ight
# 1050.7579
# 747.1289
# nanning back
# 603.38367
# nanning back
# nanpping
# nanpping
# nanpping
# nanpping
# 571.9305
# 436.2462back
# 558.7775back
# 711.38336ack
# 816.01166ack
# 910.97363
# 876.1127
# 938.32263
# 957.8323
# 1170.3296
# 1424.9917
# 1498.3718orward
# 1387.859forward
# 1202.9724orward
# 1143.702
# 1212.9636
# 1125.794
# 1090.3285
# 1108.814
# 799.16675
# 647.8229
# 392.37015eft
# nanning back
# 415.7797
# new box id: tensor(88.)
#     coords:  tensor([368.0283, 110.7136, 428.1472, 247.0178])
# last known:  tensor([336.6278,  22.1565, 455.9275, 371.8984])
# [tensor(True), tensor(False), tensor(True), tensor(False)]
# 2
#
# new box id: tensor(88.)
#     coords:  tensor([357.3192,  85.5791, 441.6376, 259.3988])
# last known:  tensor([336.6278,  22.1565, 455.9275, 371.8984])
# [tensor(True), tensor(False), tensor(True), tensor(False)]
# 2
#
# new box id: tensor(91.)
#     coords:  tensor([127.1854,  16.3334, 201.0492, 268.4617])
# last known:  tensor([336.6278,  22.1565, 455.9275, 371.8984])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(88.)
#     coords:  tensor([348.3755,  63.7412, 441.2721, 263.5005])
# last known:  tensor([336.6278,  22.1565, 455.9275, 371.8984])
# [tensor(True), tensor(True), tensor(True), tensor(False)]
# 3
#
# 2025.7968
# new box id: tensor(93.)
#     coords:  tensor([449.7966,  18.5310, 618.2875, 268.9171])
# last known:  tensor([346.2415,  57.8083, 441.9668, 263.6482])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(93.)
#     coords:  tensor([487.3871,   0.0000, 654.6525, 280.3040])
# last known:  tensor([346.2415,  57.8083, 441.9668, 263.6482])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(96.)
#     coords:  tensor([461.2026,  91.1855, 600.5092, 228.6083])
# last known:  tensor([346.2415,  57.8083, 441.9668, 263.6482])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(89.)
#     coords:  tensor([  0.6742,   0.5431, 310.5205, 296.3775])
# last known:  tensor([346.2415,  57.8083, 441.9668, 263.6482])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(96.)
#     coords:  tensor([460.3707,  91.6156, 618.9612, 229.1422])
# last known:  tensor([346.2415,  57.8083, 441.9668, 263.6482])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(89.)
#     coords:  tensor([  0.6530,   0.6340, 342.2170, 301.0660])
# last known:  tensor([346.2415,  57.8083, 441.9668, 263.6482])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(96.)
#     coords:  tensor([459.1926,  91.9170, 622.3041, 230.6951])
# last known:  tensor([346.2415,  57.8083, 441.9668, 263.6482])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(90.)
#     coords:  tensor([153.0260,   1.1668, 388.4361, 300.0693])
# last known:  tensor([346.2415,  57.8083, 441.9668, 263.6482])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(96.)
#     coords:  tensor([458.0013,  92.1914, 621.4873, 229.0982])
# last known:  tensor([346.2415,  57.8083, 441.9668, 263.6482])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(90.)
#     coords:  tensor([212.6637,   1.2433, 390.6617, 300.8367])
# last known:  tensor([346.2415,  57.8083, 441.9668, 263.6482])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(96.)
#     coords:  tensor([446.0340,  90.2240, 620.0645, 228.7060])
# last known:  tensor([346.2415,  57.8083, 441.9668, 263.6482])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(90.)
#     coords:  tensor([238.7030,   1.1627, 385.3415, 300.3064])
# last known:  tensor([346.2415,  57.8083, 441.9668, 263.6482])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(96.)
#     coords:  tensor([450.1722,  89.4495, 617.0090, 226.5439])
# last known:  tensor([346.2415,  57.8083, 441.9668, 263.6482])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(90.)
#     coords:  tensor([256.5020,   0.4524, 383.8358, 300.3918])
# last known:  tensor([346.2415,  57.8083, 441.9668, 263.6482])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(96.)
#     coords:  tensor([494.5565,  90.1131, 617.5571, 235.7160])
# last known:  tensor([346.2415,  57.8083, 441.9668, 263.6482])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(90.)
#     coords:  tensor([267.3405,   1.1149, 399.9704, 299.3767])
# last known:  tensor([346.2415,  57.8083, 441.9668, 263.6482])
# [tensor(False), tensor(False), tensor(True), tensor(True)]
# 2
#
# new box id: tensor(96.)
#     coords:  tensor([516.5831,  90.4696, 617.1212, 240.2207])
# last known:  tensor([346.2415,  57.8083, 441.9668, 263.6482])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(90.)
#     coords:  tensor([273.1824,   0.6420, 414.8979, 295.9648])
# last known:  tensor([346.2415,  57.8083, 441.9668, 263.6482])
# [tensor(False), tensor(False), tensor(True), tensor(True)]
# 2
#
# new box id: tensor(96.)
#     coords:  tensor([515.6918,  90.2191, 614.8147, 229.4713])
# last known:  tensor([346.2415,  57.8083, 441.9668, 263.6482])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(90.)
#     coords:  tensor([299.9024,   0.6823, 429.3298, 282.3690])
# last known:  tensor([346.2415,  57.8083, 441.9668, 263.6482])
# [tensor(True), tensor(False), tensor(True), tensor(True)]
# 3
#
# nan
# 1388.2957
# 1389.9429orward
# 1274.6361orward
# 1136.1824orward
# 1012.5302
# 948.98456
# 665.4255
# 468.49292ack
# 563.3202back
# 667.1887back
# 739.8433back
# 879.63586ack
# 946.36017
# 933.54706
# 937.75885
# 970.8503
# 936.15955
# 905.7778
# 873.85736
# 893.9465
# 875.41925
# 876.8533
# 898.39575
# 915.3191
# 946.72205
# nanpping
# 865.0004right
# 1090.0865
# 1030.0553
# nanpping
# 968.8897
# 1078.3124
# 1111.441
# 1112.6948
# 1113.3419
# 1133.2018
# nanpping
# nanpping
# nanpping
# nanpping
# 1292.1063
# nanning forward
# 1066.6451
# new box id: tensor(142.)
#     coords:  tensor([142.4001,   1.4665, 257.6738, 288.3456])
# last known:  tensor([244.7939,   0.0000, 410.4276, 278.9099])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(90.)
#     coords:  tensor([240.7483,   1.7179, 432.0209, 310.2289])
# last known:  tensor([244.7939,   0.0000, 410.4276, 278.9099])
# [tensor(True), tensor(True), tensor(True), tensor(True)]
# 4
#
# 530.8802
# new box id: tensor(145.)
#     coords:  tensor([281.2138, 124.6282, 350.8725, 263.4143])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(145.)
#     coords:  tensor([280.5820, 121.3388, 349.8568, 259.8061])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(145.)
#     coords:  tensor([277.7861, 121.5249, 346.7566, 258.8871])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(145.)
#     coords:  tensor([273.7238, 121.4726, 349.8333, 259.4862])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(145.)
#     coords:  tensor([272.4842, 120.8129, 353.3666, 259.9920])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(145.)
#     coords:  tensor([274.1923, 117.4822, 351.3698, 259.6873])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(145.)
#     coords:  tensor([278.5261, 107.3198, 352.3297, 260.4450])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(145.)
#     coords:  tensor([282.6679,  96.0331, 355.2657, 261.2187])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(145.)
#     coords:  tensor([284.3167,  91.2839, 358.1131, 261.6656])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(146.)
#     coords:  tensor([577.7027,  32.4614, 671.4474, 277.9859])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(145.)
#     coords:  tensor([284.5639,  88.7093, 358.9681, 261.7833])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(146.)
#     coords:  tensor([566.2386,  39.8398, 670.4904, 279.8861])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(145.)
#     coords:  tensor([284.1407,  89.1500, 360.1741, 261.7028])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(145.)
#     coords:  tensor([287.1099,  90.4350, 360.8777, 261.5626])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(140.)
#     coords:  tensor([7.5224e-02, 1.0607e+02, 8.7907e+01, 2.5680e+02])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(146.)
#     coords:  tensor([559.4078,  37.2163, 670.6924, 272.9123])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(140.)
#     coords:  tensor([7.7292e-02, 9.9730e+01, 8.6188e+01, 2.5789e+02])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(146.)
#     coords:  tensor([560.1541,  39.3189, 670.6689, 269.8358])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(140.)
#     coords:  tensor([  0.0000,  94.1740,  87.0370, 258.0453])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(146.)
#     coords:  tensor([560.9850,  40.1291, 670.2624, 268.2735])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(152.)
#     coords:  tensor([561.4042,  39.1043, 666.3343, 196.4642])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([560.9013,  39.6218, 665.9525, 134.9679])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(143.)
#     coords:  tensor([6.8160e-02, 9.3259e+01, 7.2733e+01, 1.9267e+02])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(140.)
#     coords:  tensor([1.4677e-01, 9.3405e+01, 8.5504e+01, 2.5602e+02])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(146.)
#     coords:  tensor([560.0831,  39.6669, 670.6779, 268.6573])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(152.)
#     coords:  tensor([561.1682,  38.7149, 666.2028, 192.9418])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([560.5728,  39.2325, 665.9344, 135.6240])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(143.)
#     coords:  tensor([  0.2151,  94.0214,  73.9848, 189.3795])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(140.)
#     coords:  tensor([2.4227e-01, 9.4506e+01, 8.7362e+01, 2.5552e+02])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(146.)
#     coords:  tensor([558.9100,  39.2967, 670.4704, 266.8473])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(152.)
#     coords:  tensor([561.3961,  38.6759, 665.9739, 193.1688])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([560.8786,  39.0821, 665.7173, 135.2359])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(143.)
#     coords:  tensor([  0.1879,  94.8977,  77.4514, 186.5909])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(140.)
#     coords:  tensor([  0.3510,  96.7933,  91.8309, 258.1915])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(146.)
#     coords:  tensor([559.5056,  39.0245, 670.8786, 269.0466])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(152.)
#     coords:  tensor([561.4463,  38.7336, 666.2970, 194.9033])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([561.0201,  39.1613, 666.0155, 135.7541])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(143.)
#     coords:  tensor([1.5267e-01, 9.6509e+01, 7.3100e+01, 1.8597e+02])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(140.)
#     coords:  tensor([1.8509e-01, 9.7276e+01, 9.4377e+01, 2.5734e+02])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(146.)
#     coords:  tensor([559.2949,  38.4905, 670.3408, 262.5991])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([561.0364,  38.6850, 666.5383, 196.4788])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([560.8344,  39.1029, 665.7732, 135.9338])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(143.)
#     coords:  tensor([  0.0000,  97.6291,  81.6140, 186.2880])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(147.)
#     coords:  tensor([106.0269,   1.0649, 344.0715, 295.1508])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(146.)
#     coords:  tensor([559.3564,  39.6052, 670.7928, 263.4369])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(152.)
#     coords:  tensor([560.7596,  39.2440, 667.1064, 196.5912])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([561.4473,  39.7313, 666.4724, 135.9296])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(146.)
#     coords:  tensor([560.4274,  39.9638, 668.0523, 217.4511])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([535.9623,  39.2192, 667.5129, 201.6572])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([562.0692,  39.8314, 666.0432, 136.2772])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(146.)
#     coords:  tensor([554.9498,  39.8879, 668.2595, 192.0008])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([523.2516,  38.8816, 668.6324, 211.9920])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([560.2484,  39.7043, 666.8187, 135.6685])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(145.)
#     coords:  tensor([282.2697,  97.1416, 365.3997, 266.7812])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(146.)
#     coords:  tensor([557.9103,  40.2793, 669.9290, 192.1358])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([521.2053,  38.5635, 669.6871, 213.8049])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([559.5880,  39.8522, 667.6394, 135.1407])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(154.)
#     coords:  tensor([129.3965, 117.8613, 178.6208, 258.1717])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(145.)
#     coords:  tensor([283.6252,  91.4291, 361.3489, 262.8658])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(146.)
#     coords:  tensor([560.6906,  40.3800, 670.0545, 193.8915])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([520.8676,  37.9883, 669.8846, 213.3824])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([560.3090,  40.0361, 667.1884, 135.8968])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(145.)
#     coords:  tensor([284.5646,  86.5846, 359.0834, 260.2832])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(146.)
#     coords:  tensor([561.1430,  40.3726, 669.7061, 187.6148])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([545.1481,  39.3066, 670.8200, 244.0329])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([561.2269,  40.1421, 666.5505, 136.6290])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(145.)
#     coords:  tensor([284.3543,  91.5946, 358.8051, 261.0464])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(146.)
#     coords:  tensor([561.3607,  40.4857, 669.9724, 181.8401])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([558.9738,  39.7778, 671.3552, 254.6126])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([561.8359,  40.1239, 666.6332, 136.6446])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(145.)
#     coords:  tensor([284.2831, 103.9921, 360.5190, 261.9060])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(146.)
#     coords:  tensor([564.5084,  37.4515, 669.0908, 183.8683])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([563.5212,  37.9765, 671.2535, 247.7739])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([565.1356,  37.6453, 668.2234, 135.8042])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(145.)
#     coords:  tensor([285.4333, 118.1689, 365.2852, 261.1090])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(156.)
#     coords:  tensor([1.2147e-01, 1.0152e+02, 6.0509e+01, 1.7949e+02])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(155.)
#     coords:  tensor([  1.2801,   0.8664, 196.6305, 314.0089])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(146.)
#     coords:  tensor([562.1622,  31.4674, 668.6006, 183.6021])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([557.8779,  31.2676, 671.0269, 244.1040])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([562.5883,  31.4835, 669.0539, 135.3396])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(145.)
#     coords:  tensor([291.8327, 124.8313, 372.3687, 261.2617])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(156.)
#     coords:  tensor([8.2589e-03, 1.0802e+02, 5.5673e+01, 1.9170e+02])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(157.)
#     coords:  tensor([4.7842e-02, 1.0863e+02, 5.5104e+01, 2.5004e+02])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(155.)
#     coords:  tensor([  1.1939,   0.9134, 204.0284, 316.0947])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(152.)
#     coords:  tensor([534.3767,  29.3680, 669.2436, 223.5729])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(145.)
#     coords:  tensor([300.1987, 122.3706, 381.4518, 261.2489])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(152.)
#     coords:  tensor([523.3342,  30.4197, 668.0032, 212.1531])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(145.)
#     coords:  tensor([309.5971, 121.6523, 383.1502, 261.5223])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(155.)
#     coords:  tensor([  1.0382,   1.1035, 155.2022, 314.6403])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(152.)
#     coords:  tensor([521.1987,  31.2689, 668.3184, 208.2937])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(145.)
#     coords:  tensor([315.0254, 108.1823, 376.8875, 260.0446])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(146.)
#     coords:  tensor([562.6254,  31.4060, 666.7375, 193.1636])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([521.9261,  31.7194, 668.6780, 202.7213])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([526.3917,  31.7185, 669.1614, 211.7543])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(146.)
#     coords:  tensor([558.9929,  31.8710, 666.4730, 195.5826])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([524.3273,  31.4708, 668.2695, 211.4576])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(146.)
#     coords:  tensor([557.1584,  31.9285, 665.8653, 194.7766])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([522.8742,  31.8006, 667.0449, 210.9525])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(146.)
#     coords:  tensor([559.1125,  32.0822, 665.3592, 193.8227])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([522.3303,  32.4625, 666.7607, 214.2063])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(146.)
#     coords:  tensor([561.7046,  32.5058, 665.5709, 195.5728])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([522.6857,  33.8935, 667.4214, 215.2805])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([524.0957,  34.9644, 668.4401, 217.5190])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([563.8541,  35.2048, 666.5259, 135.7316])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(146.)
#     coords:  tensor([562.8706,  34.8915, 666.1235, 192.9967])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([522.2300,  36.0541, 668.2664, 218.4028])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(162.)
#     coords:  tensor([200.0504, 115.3508, 299.9487, 263.6596])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(163.)
#     coords:  tensor([301.5122, 141.1213, 331.4829, 251.1676])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(153.)
#     coords:  tensor([564.6050,  36.4916, 666.1050, 136.0942])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(146.)
#     coords:  tensor([562.7548,  36.3111, 666.7051, 191.5246])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([521.7660,  37.3455, 668.8307, 225.4480])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([565.8433,  37.9947, 667.0383, 136.3163])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([522.9979,  37.6229, 668.8032, 221.1813])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([564.4620,  37.8242, 666.6934, 135.3472])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(164.)
#     coords:  tensor([  6.0016,  87.2689,  82.7838, 208.7995])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(166.)
#     coords:  tensor([120.0989, 114.8720, 189.1105, 263.6067])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([527.4933,  37.5326, 669.3589, 222.2324])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([564.5950,  37.4851, 666.7694, 134.9662])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(164.)
#     coords:  tensor([  1.3491,  82.2925,  82.9386, 208.3406])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(166.)
#     coords:  tensor([120.4548, 113.7205, 181.9742, 262.8403])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(152.)
#     coords:  tensor([528.5276,  37.2199, 669.2156, 217.9511])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([564.4094,  37.0934, 666.1411, 135.3285])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(164.)
#     coords:  tensor([  0.0000,  76.6283,  73.9963, 207.6524])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(166.)
#     coords:  tensor([120.7944, 107.9298, 176.9631, 261.8534])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(152.)
#     coords:  tensor([524.2141,  36.8518, 669.2716, 209.3334])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([564.4644,  36.7121, 666.4922, 135.6129])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(164.)
#     coords:  tensor([  0.0000,  71.0931,  70.5769, 207.3569])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(166.)
#     coords:  tensor([119.4196,  98.2094, 178.9090, 205.1472])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(152.)
#     coords:  tensor([520.4544,  37.0942, 670.9944, 223.1324])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([562.7991,  36.7668, 669.1973, 136.0161])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(164.)
#     coords:  tensor([  0.0000,  67.1716,  74.8162, 206.0234])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(166.)
#     coords:  tensor([115.6762,  88.1304, 180.5115, 175.6453])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(146.)
#     coords:  tensor([561.1432,  36.8731, 670.1086, 191.7985])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([521.0558,  36.4023, 670.7415, 221.7189])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([562.1733,  36.6521, 668.3244, 135.9823])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(164.)
#     coords:  tensor([  0.0000,  65.6525,  77.5729, 207.3389])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(167.)
#     coords:  tensor([ 34.2354,  82.8446, 180.0750, 251.5615])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(146.)
#     coords:  tensor([560.3755,  36.1611, 669.2625, 193.7064])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(162.)
#     coords:  tensor([204.0334, 111.1905, 297.8381, 259.6506])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([521.7717,  33.1093, 670.8991, 228.3632])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([561.9529,  35.2001, 667.8223, 135.5253])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(164.)
#     coords:  tensor([  0.0000,  68.3834,  82.6693, 209.0312])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(167.)
#     coords:  tensor([ 38.2814,  85.8079, 183.1192, 275.4302])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(146.)
#     coords:  tensor([560.5854,  33.0764, 669.4912, 193.3264])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(162.)
#     coords:  tensor([204.7931, 111.7003, 302.1846, 261.5774])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([522.3212,  33.0306, 670.8060, 221.8503])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([562.5736,  33.3614, 667.6948, 135.0644])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(164.)
#     coords:  tensor([  0.2876,  74.3850,  94.3084, 208.2557])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(167.)
#     coords:  tensor([ 45.3289,  89.0578, 186.3287, 269.3216])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(146.)
#     coords:  tensor([561.3339,  32.1763, 669.5386, 195.7947])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(162.)
#     coords:  tensor([205.2148, 112.8375, 305.7753, 262.1547])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(170.)
#     coords:  tensor([1.2062e-01, 7.5793e+01, 9.9949e+01, 2.6492e+02])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([522.2955,  35.5135, 670.0593, 231.5142])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(153.)
#     coords:  tensor([562.3870,  35.0791, 666.3459, 135.0596])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(164.)
#     coords:  tensor([  0.3214,  79.8206, 100.1350, 207.2265])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(167.)
#     coords:  tensor([ 69.6003,  89.1141, 188.4995, 268.0930])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(162.)
#     coords:  tensor([205.4971, 109.8321, 306.8694, 262.0599])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(170.)
#     coords:  tensor([1.8023e-01, 8.1597e+01, 1.0156e+02, 2.6924e+02])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([522.4929,  35.7290, 665.5419, 226.6676])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(164.)
#     coords:  tensor([1.0745e-01, 8.2516e+01, 9.6750e+01, 2.0764e+02])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(167.)
#     coords:  tensor([ 79.7674,  88.5994, 189.3285, 268.0924])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(162.)
#     coords:  tensor([205.2601, 107.3581, 306.9835, 262.4117])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(170.)
#     coords:  tensor([1.1380e-01, 8.4004e+01, 9.8148e+01, 2.6777e+02])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([522.3085,  34.8451, 664.5045, 225.2547])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(164.)
#     coords:  tensor([  0.0000,  83.6360,  96.5321, 211.3210])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(167.)
#     coords:  tensor([ 77.2799,  88.4426, 188.2296, 267.9343])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(162.)
#     coords:  tensor([204.4987, 106.0367, 305.2325, 262.3779])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(152.)
#     coords:  tensor([522.3177,  33.5500, 665.8745, 224.3837])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(164.)
#     coords:  tensor([7.9565e-02, 8.4691e+01, 8.3990e+01, 2.1481e+02])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(167.)
#     coords:  tensor([ 71.6001,  88.4432, 185.2660, 267.4847])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(162.)
#     coords:  tensor([202.8818, 105.4499, 304.3530, 261.2370])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(170.)
#     coords:  tensor([1.5631e-01, 8.5036e+01, 9.8014e+01, 2.5119e+02])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(152.)
#     coords:  tensor([522.7841,  33.0949, 665.3790, 211.0056])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(164.)
#     coords:  tensor([6.0721e-02, 8.5281e+01, 7.4382e+01, 2.4567e+02])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(167.)
#     coords:  tensor([ 55.1098,  87.5685, 183.9244, 266.7553])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(162.)
#     coords:  tensor([200.2554, 105.7329, 295.0451, 261.9561])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(170.)
#     coords:  tensor([9.5744e-02, 8.4801e+01, 8.0099e+01, 2.1963e+02])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(152.)
#     coords:  tensor([523.0995,  32.3730, 668.0934, 205.3684])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(167.)
#     coords:  tensor([ 51.3467,  87.3209, 184.1729, 265.6729])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(True)]
# 1
#
# new box id: tensor(162.)
#     coords:  tensor([199.5554, 103.3961, 288.8511, 263.2180])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(170.)
#     coords:  tensor([1.4653e-01, 8.5387e+01, 7.2461e+01, 2.0645e+02])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(152.)
#     coords:  tensor([523.0383,  32.2382, 669.3387, 201.5920])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# ...
# 2
#
# new box id: tensor(240.)
#     coords:  tensor([319.8062, 120.3701, 370.0563, 185.2819])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(241.)
#     coords:  tensor([305.9154, 119.2123, 409.8739, 259.0842])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(225.)
#     coords:  tensor([554.5786,  22.4592, 670.9007, 147.4504])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(269.)
#     coords:  tensor([364.3511, 139.8197, 413.1625, 256.4220])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(178.)
#     coords:  tensor([304.5123, 119.5280, 374.8381, 258.6681])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(162.)
#     coords:  tensor([215.7473, 111.1847, 302.1202, 260.0958])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(235.)
#     coords:  tensor([554.5721,  21.3758, 671.9601, 266.3248])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(240.)
#     coords:  tensor([319.9815, 120.5895, 369.7626, 185.1746])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(241.)
#     coords:  tensor([305.9919, 119.1707, 409.3607, 259.2578])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(225.)
#     coords:  tensor([555.0035,  22.1625, 670.7646, 146.8010])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(269.)
#     coords:  tensor([364.5889, 139.9832, 413.1453, 256.3621])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(178.)
#     coords:  tensor([304.5875, 119.2559, 374.0376, 258.9731])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(162.)
#     coords:  tensor([214.6269, 111.0238, 303.4691, 259.4502])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(235.)
#     coords:  tensor([554.6229,  20.9011, 671.9720, 266.8626])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(240.)
#     coords:  tensor([321.1058, 120.4512, 369.8757, 185.1053])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(241.)
#     coords:  tensor([305.9062, 119.1403, 410.5562, 259.2479])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(225.)
#     coords:  tensor([555.1465,  21.8654, 670.8094, 145.3309])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(269.)
#     coords:  tensor([364.4764, 140.4120, 413.8832, 256.7242])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(178.)
#     coords:  tensor([305.1767, 119.4738, 376.3113, 258.6217])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(162.)
#     coords:  tensor([214.2007, 110.7986, 304.6223, 260.1293])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(235.)
#     coords:  tensor([554.5385,  20.8188, 671.9442, 267.5370])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(240.)
#     coords:  tensor([321.7268, 120.4090, 370.1121, 185.1149])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(241.)
#     coords:  tensor([305.9589, 119.1019, 410.6445, 259.2097])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(225.)
#     coords:  tensor([555.2297,  21.7761, 670.8464, 145.3219])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(269.)
#     coords:  tensor([364.9444, 140.4474, 414.2852, 256.5799])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(178.)
#     coords:  tensor([304.7928, 119.6994, 376.0919, 258.5151])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(162.)
#     coords:  tensor([214.0147, 110.4793, 303.4683, 259.4258])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(235.)
#     coords:  tensor([554.4557,  20.8515, 671.9552, 268.0237])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(240.)
#     coords:  tensor([321.8089, 120.3831, 370.1529, 185.2753])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(241.)
#     coords:  tensor([305.7083, 119.2668, 411.2809, 259.2000])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(225.)
#     coords:  tensor([555.1953,  21.5101, 670.8542, 144.3686])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(269.)
#     coords:  tensor([365.2513, 140.4915, 413.8199, 256.7677])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(178.)
#     coords:  tensor([304.2252, 119.8033, 375.6691, 258.6498])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(162.)
#     coords:  tensor([214.1106, 110.6265, 304.4214, 259.8384])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(235.)
#     coords:  tensor([554.3046,  21.2359, 671.8682, 267.8551])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(240.)
#     coords:  tensor([321.2104, 120.3793, 370.2299, 185.6182])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(241.)
#     coords:  tensor([305.6441, 119.3136, 411.3560, 259.2383])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(225.)
#     coords:  tensor([555.1473,  21.7945, 670.8616, 145.0915])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(269.)
#     coords:  tensor([365.6395, 140.5492, 414.0060, 256.9719])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(178.)
#     coords:  tensor([304.1599, 119.9261, 376.2465, 258.4203])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(270.)
#     coords:  tensor([ 67.6976,  78.7972, 126.1469, 164.5176])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(162.)
#     coords:  tensor([214.1905, 111.4878, 301.1703, 260.7906])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(235.)
#     coords:  tensor([554.6139,  21.1217, 671.8798, 267.1591])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(240.)
#     coords:  tensor([319.8207, 120.1987, 370.1036, 185.8216])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(241.)
#     coords:  tensor([305.6427, 119.1474, 411.0076, 259.2818])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(225.)
#     coords:  tensor([555.2552,  22.2466, 671.3818, 168.0068])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(269.)
#     coords:  tensor([365.3266, 140.3974, 413.8860, 257.2433])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(178.)
#     coords:  tensor([304.1763, 119.7054, 375.6708, 258.2183])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(235.)
#     coords:  tensor([554.4508,  21.9758, 671.6644, 265.7010])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(240.)
#     coords:  tensor([320.0630, 120.2090, 370.0295, 185.6015])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(241.)
#     coords:  tensor([305.7390, 119.2254, 410.3694, 259.3784])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(225.)
#     coords:  tensor([555.1450,  22.7791, 671.5364, 157.7764])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(269.)
#     coords:  tensor([365.2927, 140.4246, 413.2737, 257.4329])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(178.)
#     coords:  tensor([304.3270, 119.7171, 375.7270, 258.4105])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(235.)
#     coords:  tensor([553.8049,  22.9375, 671.5250, 265.5617])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(240.)
#     coords:  tensor([319.9492, 120.4574, 370.2870, 185.5068])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(241.)
#     coords:  tensor([305.7432, 119.4417, 409.7665, 259.3452])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(225.)
#     coords:  tensor([554.7274,  23.4320, 671.5366, 146.0266])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(269.)
#     coords:  tensor([365.7918, 140.5299, 413.3276, 257.0501])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(178.)
#     coords:  tensor([304.5590, 119.5540, 377.2975, 259.0542])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(162.)
#     coords:  tensor([214.3342, 111.5910, 304.5268, 260.3338])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(235.)
#     coords:  tensor([553.9382,  23.7105, 671.7483, 265.8091])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
#
# new box id: tensor(240.)
#     coords:  tensor([319.6968, 120.7933, 370.1583, 185.2692])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(241.)
#     coords:  tensor([305.6096, 119.4866, 410.7879, 259.3689])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(225.)
#     coords:  tensor([555.2174,  24.3906, 671.5688, 145.9869])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(269.)
#     coords:  tensor([364.9526, 140.4946, 414.0236, 256.9917])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(True), tensor(False)]
# 1
#
# new box id: tensor(178.)
#     coords:  tensor([304.4586, 119.4868, 379.4184, 259.5294])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(False), tensor(False), tensor(False)]
# 0
#
# new box id: tensor(162.)
#     coords:  tensor([214.6540, 111.1095, 301.6588, 261.1695])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(True), tensor(False), tensor(False), tensor(False)]
# 1
#
# new box id: tensor(235.)
#     coords:  tensor([554.0721,  24.2941, 671.8948, 266.4256])
# last known:  tensor([240.2329,   1.1982, 434.3623, 313.2299])
# [tensor(False), tensor(True), tensor(False), tensor(True)]
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 75
#      72 camera.retrieve_measure(depth_mat, measure=sl.MEASURE.DEPTH)
#      73 depth = depth_mat.get_data()
# ---> 75 tracked_box = m.track(image, return_type="corners")
#      77 if tracked_box is False:
#      78     image_display.value = bytes(cv2.imencode('.jpg', image)[1])
#
# File ~/Documents/notebooks/tracking.py:70, in Model.track(self, image, return_type)
#      65 for i in range(len(self.result.boxes.id)):
#      66
#      67     # ignore objects that appeared at the same time as original tracked object
#      68     if self.result.boxes.id[i] not in self.ignore_ids:
# ---> 70         coords = self.result.boxes.xyxy[i]
#      71         print("new box id: " + str(self.result.boxes.id[i]))
#      72         print("    coords: ", coords)
#
# File /usr/local/lib/python3.10/dist-packages/ultralytics/engine/results.py:1076, in Boxes.xyxy(self)
#    1073     self.is_track = n == 7
#    1074     self.orig_shape = orig_shape
# -> 1076 @property
#    1077 def xyxy(self):
#    1078     """
#    1079     Returns bounding boxes in [x1, y1, x2, y2] format.
#    1080
#    (...)
#    1089         >>> print(xyxy)
#    1090     """
#    1091     return self.data[:, :4]
#
# KeyboardInterrupt:
